# %%
import gensim
from gensim.models import Word2Vec

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %% [markdown]
# ### Prepare the data

# %%
# with open("word_corpus.txt") as f:
#     corpus_text = f.readlines()
# corpus_text

# %%
corpus_text = [
    # --- TOPIC 1: FOOD & FRUITS ---
    "I eat mango and apple everyday",
    "Mango is a very sweet and delicious fruit",
    "Apple pie is a tasty dessert",
    "Banana is yellow and good for health",
    "Fruits like mango apple and banana are healthy",
    "I love eating pizza and burger for dinner",
    "Burger is a fast food",
    "Pizza contains cheese and tomato sauce",
    "I am hungry I want to eat food",
    "Restaurant serves delicious meals",
    "Vegetables and fruits are essential for diet",
    "Cook dinner in the kitchen",
    "Sweet desserts like cake and chocolate",

    # --- TOPIC 2: SPORTS & GAMES ---
    "Cricket is a popular sport in India",
    "Virat Kohli plays cricket for the team",
    "Football is played with a ball in a stadium",
    "Messi is a famous football player",
    "Players run fast to score a goal",
    "Tennis is played with a racket and ball",
    "The match was played in a big stadium",
    "The team won the championship trophy",
    "Athletes run in the olympics",
    "Bat and ball are used in cricket matches",
    "Score runs to win the cricket game",
    "The referee blew the whistle",

    # --- TOPIC 3: TECHNOLOGY & CODING ---
    "Python is a popular programming language",
    "Computers use binary code to process data",
    "Artificial Intelligence and machine learning are the future",
    "Data science involves statistics and algorithms",
    "Software developers write code in java and python",
    "The computer requires a keyboard and mouse",
    "Internet connects computers globally",
    "Deep learning models use neural networks",
    "Robots are built using engineering and ai",
    "The server stores massive amounts of data",
    "Programmers debug the software code",
    "Technology is advancing rapidly"
]

# %% [markdown]
# ### Preprocessing the text

# %%
tokenized_text = [gensim.utils.simple_preprocess(sent) for sent in corpus_text]

# %%
tokenized_text
# Out:
# [['eat', 'mango', 'and', 'apple', 'everyday'],
#  ['mango', 'is', 'very', 'sweet', 'and', 'delicious', 'fruit'],
#  ['apple', 'pie', 'is', 'tasty', 'dessert'],
#  ['banana', 'is', 'yellow', 'and', 'good', 'for', 'health'],
#  ['fruits', 'like', 'mango', 'apple', 'and', 'banana', 'are', 'healthy'],
#  ['love', 'eating', 'pizza', 'and', 'burger', 'for', 'dinner'],
#  ['burger', 'is', 'fast', 'food'],
#  ['pizza', 'contains', 'cheese', 'and', 'tomato', 'sauce'],
#  ['am', 'hungry', 'want', 'to', 'eat', 'food'],
#  ['restaurant', 'serves', 'delicious', 'meals'],
#  ['vegetables', 'and', 'fruits', 'are', 'essential', 'for', 'diet'],
#  ['cook', 'dinner', 'in', 'the', 'kitchen'],
#  ['sweet', 'desserts', 'like', 'cake', 'and', 'chocolate'],
#  ['cricket', 'is', 'popular', 'sport', 'in', 'india'],
#  ['virat', 'kohli', 'plays', 'cricket', 'for', 'the', 'team'],
#  ['football', 'is', 'played', 'with', 'ball', 'in', 'stadium'],
#  ['messi', 'is', 'famous', 'football', 'player'],
#  ['players', 'run', 'fast', 'to', 'score', 'goal'],
#  ['tennis', 'is', 'played', 'with', 'racket', 'and', 'ball'],
#  ['the', 'match', 'was', 'played', 'in', 'big', 'stadium'],
#  ['the', 'team', 'won', 'the', 'championship', 'trophy'],
#  ['athletes', 'run', 'in', 'the', 'olympics'],
#  ['bat', 'and', 'ball', 'are', 'used', 'in', 'cricket', 'matches'],
#  ['score', 'runs', 'to', 'win', 'the', 'cricket', 'game'],
#  ['the', 'referee', 'blew', 'the', 'whistle'],
#  ['python', 'is', 'popular', 'programming', 'language'],
#  ['computers', 'use', 'binary', 'code', 'to', 'process', 'data'],
#  ['artificial',
#   'intelligence',
#   'and',
#   'machine',
#   'learning',
#   'are',
#   'the',
#   'future'],
#  ['data', 'science', 'involves', 'statistics', 'and', 'algorithms'],
#  ['software', 'developers', 'write', 'code', 'in', 'java', 'and', 'python'],
#  ['the', 'computer', 'requires', 'keyboard', 'and', 'mouse'],
#  ['internet', 'connects', 'computers', 'globally'],
#  ['deep', 'learning', 'models', 'use', 'neural', 'networks'],
#  ['robots', 'are', 'built', 'using', 'engineering', 'and', 'ai'],
#  ['the', 'server', 'stores', 'massive', 'amounts', 'of', 'data'],
#  ['programmers', 'debug', 'the', 'software', 'code'],
#  ['technology', 'is', 'advancing', 'rapidly']]

# %% [markdown]
# ### Build model

# %%
model = Word2Vec(
    sentences=tokenized_text,
    vector_size=5,
    window=5,
    sg=1,
    min_count=1,
    workers=4)

# %%
model.wv['mango']
# Out:
# array([ 0.04908652, -0.01715992,  0.11232613, -0.05565822,  0.04441647],
#       dtype=float32)

# %%
model.wv['apple']
# Out:
# array([-0.03168083,  0.0064003 , -0.08224421, -0.15476932, -0.03101677],
#       dtype=float32)

# %%
model.wv['cricket']
# Out:
# array([-0.06820968, -0.01848307,  0.11653265, -0.15187551, -0.079815  ],
#       dtype=float32)

# %%
model.wv.most_similar('mango')
# Out:
# [('diet', 0.9462408423423767),
#  ('health', 0.9196646213531494),
#  ('players', 0.8988900780677795),
#  ('team', 0.8987223505973816),
#  ('contains', 0.8107606768608093),
#  ('championship', 0.800618052482605),
#  ('popular', 0.7862182259559631),
#  ('used', 0.7829359769821167),
#  ('programmers', 0.7600233554840088),
#  ('involves', 0.7539288997650146)]

# %%
model.wv.most_similar('apple')
# Out:
# [('plays', 0.9465010166168213),
#  ('robots', 0.8618748188018799),
#  ('future', 0.8353472352027893),
#  ('built', 0.7848122119903564),
#  ('dessert', 0.7691301703453064),
#  ('famous', 0.7226020693778992),
#  ('advancing', 0.6733610033988953),
#  ('in', 0.6641463041305542),
#  ('technology', 0.662768542766571),
#  ('data', 0.6612134575843811)]

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity([model.wv['fruit']], [model.wv['banana']])
# Out:
# array([[0.83063805]], dtype=float32)

# %%
import gensim.downloader
model = gensim.downloader.load('word2vec-google-news-300')
cosine_similarity([model.wv['fruit']], [model.wv['banana']])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 3
#       1 import gensim.downloader
#       2 model = gensim.downloader.load('word2vec-google-news-300')
# ----> 3 cosine_similarity([model.wv['fruit']], [model.wv['banana']])
#
# AttributeError: 'KeyedVectors' object has no attribute 'wv'

# %%
list1=['mango','banana','football']

# %%
model.wv.doesnt_match(list1)
# Out:
# 'banana'

# %% [markdown]
# Visualization

# %%
vectors=[model.wv[w] for w in tokenized_text]
len(vectors)
# Out:
# 37

# %%
vectors
# Out:
# [array([[-0.1872339 ,  0.07695899,  0.09831577, -0.12961948,  0.02379374],
#         [ 0.04908652, -0.01715992,  0.11232613, -0.05565822,  0.04441647],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.03168083,  0.0064003 , -0.08224421, -0.15476932, -0.03101677],
#         [ 0.12255615, -0.12838943, -0.13462566,  0.05088089, -0.03227091]],
#        dtype=float32),
#  array([[ 0.04908652, -0.01715992,  0.11232613, -0.05565822,  0.04441647],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [-0.14897776,  0.09232993,  0.1237267 , -0.06029899,  0.13238461],
#         [-0.13467659, -0.14076966, -0.04653368,  0.09994826, -0.07361437],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.0750598 , -0.17391479,  0.11083749,  0.12875602, -0.0159074 ],
#         [-0.0371276 ,  0.13012205, -0.05391257,  0.09636763,  0.13805556]],
#        dtype=float32),
#  array([[-0.03168083,  0.0064003 , -0.08224421, -0.15476932, -0.03101677],
#         [ 0.12146341, -0.11997014, -0.09195375, -0.14584006, -0.08749364],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [-0.00648214, -0.09078877,  0.13371688,  0.02860018, -0.06738099],
#         [-0.18150371, -0.04649364, -0.17191891, -0.14211537, -0.16826227]],
#        dtype=float32),
#  array([[ 0.10736673,  0.1553745 , -0.11527971,  0.14872085,  0.13219568],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [-0.00541374, -0.17656101, -0.17202365,  0.055871  , -0.16419862],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.19337156, -0.15550664, -0.19849776, -0.08698989, -0.05364123],
#         [-0.03838642,  0.16310978, -0.11615904, -0.0006516 , -0.09526772],
#         [ 0.145458  , -0.11517236,  0.16667296, -0.14546326,  0.06802966]],
#        dtype=float32),
#  array([[-0.17016014,  0.06438267, -0.09228715, -0.10184716,  0.07099772],
#         [ 0.1679136 ,  0.18024491,  0.13160695, -0.01447954,  0.15397312],
#         [ 0.04908652, -0.01715992,  0.11232613, -0.05565822,  0.04441647],
#         [-0.03168083,  0.0064003 , -0.08224421, -0.15476932, -0.03101677],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.10736673,  0.1553745 , -0.11527971,  0.14872085,  0.13219568],
#         [ 0.14614871,  0.10187308,  0.13568509,  0.01444069,  0.1269494 ],
#         [ 0.03397913, -0.13850977, -0.17338079, -0.1183758 , -0.17934725]],
#        dtype=float32),
#  array([[ 0.13264601,  0.17866066, -0.01299325,  0.05884346, -0.12232909],
#         [ 0.04803454, -0.03685941, -0.098925  ,  0.00367489, -0.04030493],
#         [ 0.1568562 , -0.18950488, -0.00334794,  0.06890613, -0.01837227],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.15811308,  0.1190356 , -0.02991295,  0.03000185,  0.03503836],
#         [-0.03838642,  0.16310978, -0.11615904, -0.0006516 , -0.09526772],
#         [ 0.15794176, -0.13881874, -0.18185212, -0.0078044 , -0.06226015]],
#        dtype=float32),
#  array([[ 0.15811308,  0.1190356 , -0.02991295,  0.03000185,  0.03503836],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [ 0.05554636,  0.13787667,  0.12283613,  0.19066179,  0.18534519],
#         [ 0.19912465, -0.08724828, -0.01161807, -0.11437321,  0.07720233]],
#        dtype=float32),
#  array([[ 1.56856194e-01, -1.89504877e-01, -3.34793818e-03,
#           6.89061284e-02, -1.83722675e-02],
#         [ 2.28731222e-02, -4.57860790e-02,  1.88115135e-01,
#           2.40525417e-02,  2.90220343e-02],
#         [-1.67379305e-02,  1.83655813e-01,  1.35786459e-01,
#           2.94551887e-02, -1.77905545e-01],
#         [-9.92184225e-03,  5.57161169e-03,  1.06414020e-01,
#           1.77062109e-01, -1.87981665e-01],
#         [ 1.17961854e-01,  3.06584165e-02, -1.41043048e-02,
#           1.86477989e-01, -9.88958403e-02],
#         [ 2.33228058e-02,  1.22503325e-01,  1.19047181e-05,
#          -6.52755499e-02, -3.05189192e-02]], dtype=float32),
#  array([[ 0.16267586, -0.0888415 , -0.02097231,  0.01969968, -0.003977  ],
#         [ 0.10189545, -0.03114173, -0.17313147,  0.05830875, -0.13411362],
#         [ 0.18194963,  0.1788336 , -0.16318277, -0.06110493,  0.19721493],
#         [-0.15109278, -0.01827431,  0.19462985, -0.14938027, -0.04746788],
#         [-0.1872339 ,  0.07695899,  0.09831577, -0.12961948,  0.02379374],
#         [ 0.19912465, -0.08724828, -0.01161807, -0.11437321,  0.07720233]],
#        dtype=float32),
#  array([[-0.17444807, -0.10155079,  0.18633026, -0.03772668,  0.05838118],
#         [ 0.1472607 , -0.13453022,  0.11294992, -0.1908748 , -0.01613729],
#         [-0.0750598 , -0.17391479,  0.11083749,  0.12875602, -0.0159074 ],
#         [ 0.16615213, -0.18678339,  0.06900597,  0.00478393,  0.07686044]],
#        dtype=float32),
#  array([[ 0.04719345,  0.12298442,  0.1604078 ,  0.1145228 , -0.01566638],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.17016014,  0.06438267, -0.09228715, -0.10184716,  0.07099772],
#         [ 0.14614871,  0.10187308,  0.13568509,  0.01444069,  0.1269494 ],
#         [ 0.05272992,  0.01533158,  0.04809812, -0.15014604, -0.18694995],
#         [-0.03838642,  0.16310978, -0.11615904, -0.0006516 , -0.09526772],
#         [ 0.16819493, -0.01294949,  0.1842333 , -0.16418831,  0.07513366]],
#        dtype=float32),
#  array([[ 0.04884133,  0.19826606, -0.15327467, -0.1392153 , -0.15450807],
#         [ 0.15794176, -0.13881874, -0.18185212, -0.0078044 , -0.06226015],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.05493756, -0.16659023,  0.1573385 ,  0.17094266, -0.19194084]],
#        dtype=float32),
#  array([[-0.13467659, -0.14076966, -0.04653368,  0.09994826, -0.07361437],
#         [-0.06470015, -0.01193507,  0.1511787 , -0.01578558, -0.03273451],
#         [ 0.1679136 ,  0.18024491,  0.13160695, -0.01447954,  0.15397312],
#         [ 0.190962  , -0.14685576, -0.14440885, -0.04613311, -0.01632525],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.18552352,  0.11972919,  0.10174189,  0.10104463, -0.0647816 ]],
#        dtype=float32),
#  array([[-0.06820968, -0.01848307,  0.11653265, -0.15187551, -0.079815  ],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [ 0.05788105, -0.09797402,  0.08921621, -0.03570295,  0.1336491 ],
#         [ 0.11444305, -0.17502297, -0.08965391, -0.16345848,  0.00023254],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [-0.0733747 ,  0.06254409, -0.19115558,  0.02954438,  0.1301145 ]],
#        dtype=float32),
#  array([[-0.17911115, -0.01467788,  0.16341716,  0.15293   , -0.14439489],
#         [-0.1675172 , -0.12093363, -0.11318526, -0.04690122, -0.0344846 ],
#         [-0.10092031, -0.0455393 , -0.14327015, -0.19355704, -0.05583391],
#         [-0.06820968, -0.01848307,  0.11653265, -0.15187551, -0.079815  ],
#         [-0.03838642,  0.16310978, -0.11615904, -0.0006516 , -0.09526772],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.04701218, -0.09030931,  0.16840225, -0.19811463,  0.13421114]],
#        dtype=float32),
#  array([[ 0.14358866,  0.13696167,  0.15301366, -0.0779589 , -0.01237785],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [-0.08930839,  0.09151216, -0.1336367 , -0.07298612,  0.18670684],
#         [-0.00854785, -0.16609643, -0.10938147,  0.13908361,  0.06539443],
#         [-0.16402237,  0.09027366, -0.08125302,  0.01400934,  0.16982129],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [-0.12414254,  0.02278025,  0.12346564, -0.05898657, -0.12412154]],
#        dtype=float32),
#  array([[-0.02923614,  0.0894329 ,  0.07630381, -0.13241382, -0.138041  ],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [-0.17485392,  0.04256934, -0.01691888, -0.18722919, -0.18899463],
#         [ 0.14358866,  0.13696167,  0.15301366, -0.0779589 , -0.01237785],
#         [-0.16156656,  0.12485383,  0.09745546,  0.0147545 ,  0.06015791]],
#        dtype=float32),
#  array([[ 0.06257606, -0.09405594,  0.10609129, -0.08499275,  0.05288352],
#         [-0.1718608 ,  0.07346305,  0.10394186,  0.1149037 ,  0.14920522],
#         [ 0.05554636,  0.13787667,  0.12283613,  0.19066179,  0.18534519],
#         [-0.15109278, -0.01827431,  0.19462985, -0.14938027, -0.04746788],
#         [ 0.10057955, -0.17752133, -0.13951851,  0.01666451,  0.12687992],
#         [-0.16250876,  0.1661491 ,  0.04066515, -0.18705595, -0.09576525]],
#        dtype=float32),
#  array([[-0.16008462, -0.15256391,  0.05990892, -0.05744571, -0.1384687 ],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [-0.08930839,  0.09151216, -0.1336367 , -0.07298612,  0.18670684],
#         [-0.00854785, -0.16609643, -0.10938147,  0.13908361,  0.06539443],
#         [ 0.13798627, -0.04734712,  0.17635629,  0.15090603, -0.19069174],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.16402237,  0.09027366, -0.08125302,  0.01400934,  0.16982129]],
#        dtype=float32),
#  array([[-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [-0.11319614,  0.11899095, -0.061198  ,  0.06736957,  0.05992664],
#         [-0.01974619,  0.19970517,  0.18475634, -0.09137493,  0.18066077],
#         [-0.08930839,  0.09151216, -0.1336367 , -0.07298612,  0.18670684],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [ 0.09638542, -0.12274228,  0.05186762,  0.01374038, -0.0682795 ],
#         [-0.12414254,  0.02278025,  0.12346564, -0.05898657, -0.12412154]],
#        dtype=float32),
#  array([[-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.04701218, -0.09030931,  0.16840225, -0.19811463,  0.13421114],
#         [-0.14668445, -0.19357596, -0.18044743, -0.02147915, -0.13045149],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.08025828,  0.08694568,  0.20054458, -0.09014906, -0.02838784],
#         [-0.1386962 ,  0.06844448,  0.00541252,  0.09446494, -0.14301768]],
#        dtype=float32),
#  array([[ 0.03550522, -0.13653784, -0.19401515,  0.18041013,  0.12388713],
#         [-0.1718608 ,  0.07346305,  0.10394186,  0.1149037 ,  0.14920522],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [-0.125419  , -0.05947995,  0.07017202, -0.01559486,  0.02774814]],
#        dtype=float32),
#  array([[ 0.13698624,  0.04479625,  0.02316378, -0.18712701,  0.16915363],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.16402237,  0.09027366, -0.08125302,  0.01400934,  0.16982129],
#         [ 0.14614871,  0.10187308,  0.13568509,  0.01444069,  0.1269494 ],
#         [ 0.01644631,  0.01513219,  0.11099452, -0.17285767,  0.01127774],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [-0.06820968, -0.01848307,  0.11653265, -0.15187551, -0.079815  ],
#         [ 0.0150643 , -0.16934398,  0.15743314,  0.18396667, -0.05558055]],
#        dtype=float32),
#  array([[ 0.10057955, -0.17752133, -0.13951851,  0.01666451,  0.12687992],
#         [-0.0850397 , -0.06127843,  0.11434524,  0.11494385, -0.10003796],
#         [-0.15109278, -0.01827431,  0.19462985, -0.14938027, -0.04746788],
#         [-0.12699233,  0.09393633, -0.16261159,  0.03893049, -0.10145526],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [-0.06820968, -0.01848307,  0.11653265, -0.15187551, -0.079815  ],
#         [ 0.11637347,  0.02435531,  0.04407971, -0.08354367,  0.14343776]],
#        dtype=float32),
#  array([[-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [-0.14287764,  0.02529302, -0.14298628, -0.04527051,  0.07461324],
#         [-0.00935117,  0.11783478, -0.14779674, -0.05096569, -0.11164187],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [-0.1487892 , -0.02100721, -0.01534849, -0.05141482,  0.19341299]],
#        dtype=float32),
#  array([[ 0.03245896,  0.00398973,  0.07100908,  0.00287958,  0.19226491],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [ 0.05788105, -0.09797402,  0.08921621, -0.03570295,  0.1336491 ],
#         [-0.0556225 ,  0.17997016,  0.10537424, -0.04442543, -0.18982123],
#         [-0.10543422,  0.12209972,  0.08889963,  0.05064641, -0.02995454]],
#        dtype=float32),
#  array([[ 0.03638418,  0.12251993, -0.09240159, -0.06382084,  0.13501328],
#         [-0.0179498 ,  0.05721949,  0.11034534,  0.13916126, -0.11473557],
#         [-0.09662885, -0.10533845,  0.14209032, -0.11748924,  0.04178781],
#         [-0.00770587, -0.15322803,  0.19772147,  0.09441694,  0.18260321],
#         [-0.15109278, -0.01827431,  0.19462985, -0.14938027, -0.04746788],
#         [ 0.1146851 , -0.07796065, -0.02157832,  0.19721305, -0.04613954],
#         [-0.19363977,  0.10140441, -0.1698711 , -0.09055927, -0.00225194]],
#        dtype=float32),
#  array([[-0.11681622, -0.0157555 ,  0.16320932, -0.048684  , -0.19388174],
#         [ 0.00578064,  0.09972131,  0.15512623, -0.02347238,  0.08627915],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.00255442,  0.04038691,  0.18985583,  0.11040237, -0.08627198],
#         [ 0.01145963,  0.1496129 , -0.01442612, -0.05420433, -0.17548813],
#         [ 0.14614871,  0.10187308,  0.13568509,  0.01444069,  0.1269494 ],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.08489008,  0.00173159, -0.18952718, -0.19530508, -0.12412215]],
#        dtype=float32),
#  array([[-0.19363977,  0.10140441, -0.1698711 , -0.09055927, -0.00225194],
#         [ 0.05621082,  0.05841862, -0.04568346, -0.06352629, -0.04744543],
#         [ 0.06835979,  0.10371192,  0.12684624, -0.05735283,  0.14579187],
#         [ 0.17596321,  0.18532954, -0.11838811, -0.1895524 ,  0.19516894],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.01350658, -0.07611556, -0.1426055 , -0.04235881,  0.07846809]],
#        dtype=float32),
#  array([[ 0.10890578,  0.16724247, -0.02744468, -0.18578927,  0.08701618],
#         [ 0.04897165,  0.12366266,  0.07879066,  0.03926456,  0.0082979 ],
#         [ 0.03287531, -0.04367054,  0.19253589,  0.18884182, -0.19651687],
#         [-0.00770587, -0.15322803,  0.19772147,  0.09441694,  0.18260321],
#         [-0.0365586 ,  0.0575374 ,  0.0207347 , -0.16671057, -0.18935482],
#         [-0.04328015,  0.17661998, -0.1054906 , -0.16282359,  0.13635515],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.03245896,  0.00398973,  0.07100908,  0.00287958,  0.19226491]],
#        dtype=float32),
#  array([[-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.18757743,  0.09429471,  0.08036195, -0.1259857 ,  0.16900794],
#         [-0.08241194,  0.05616689,  0.140983  ,  0.12044209, -0.15098043],
#         [-0.16419727,  0.18680076, -0.00123013, -0.04094456,  0.09176347],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [ 0.10760761,  0.11833593,  0.01165763,  0.16308689, -0.1405632 ]],
#        dtype=float32),
#  array([[-0.09040986,  0.1144589 ,  0.18422349, -0.08279496,  0.15918604],
#         [-0.11514845, -0.09454561, -0.14615625,  0.1658165 ,  0.00216533],
#         [ 0.03638418,  0.12251993, -0.09240159, -0.06382084,  0.13501328],
#         [ 0.02414013, -0.16876732, -0.16352108, -0.00552616,  0.02412569]],
#        dtype=float32),
#  array([[ 0.16695659,  0.19295806,  0.0785957 , -0.0584171 , -0.00075894],
#         [ 0.01145963,  0.1496129 , -0.01442612, -0.05420433, -0.17548813],
#         [ 0.07990388,  0.10398261,  0.08588266,  0.03804336, -0.06394737],
#         [-0.0179498 ,  0.05721949,  0.11034534,  0.13916126, -0.11473557],
#         [ 0.18879472,  0.15399097,  0.11116204, -0.1379901 ,  0.11636397],
#         [ 0.0853419 , -0.07469547,  0.16909395,  0.0289943 , -0.1456225 ]],
#        dtype=float32),
#  array([[-0.11854619, -0.03649928, -0.08313454, -0.13337708, -0.07474756],
#         [ 0.14614871,  0.10187308,  0.13568509,  0.01444069,  0.1269494 ],
#         [ 0.02767873, -0.05066492, -0.13649285, -0.16010773, -0.18387784],
#         [ 0.08983905,  0.03038864, -0.05130759, -0.09017193, -0.02227424],
#         [-0.11144904,  0.03586064, -0.01520446,  0.13333838,  0.07849255],
#         [-0.00992184,  0.00557161,  0.10641402,  0.17706211, -0.18798167],
#         [-0.03196553, -0.0068109 ,  0.06892022,  0.02555231, -0.01837985]],
#        dtype=float32),
#  array([[-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.10793633, -0.1475093 , -0.14596076, -0.05116463, -0.17350145],
#         [-0.09848651,  0.16981448,  0.10824734, -0.13352528,  0.07889348],
#         [-0.14259045, -0.09599181, -0.07198778, -0.17433591,  0.15820025],
#         [-0.12362257,  0.10618511,  0.20355456, -0.17402288, -0.10393178],
#         [-0.09370739, -0.06223625,  0.18910089,  0.01574907,  0.14963105],
#         [-0.19363977,  0.10140441, -0.1698711 , -0.09055927, -0.00225194]],
#        dtype=float32),
#  array([[ 0.14665239, -0.07328895,  0.05407538, -0.166808  ,  0.12364221],
#         [ 0.00195349,  0.06176529, -0.13509499, -0.02906672,  0.1534646 ],
#         [-0.14302082,  0.13119176,  0.18496768, -0.10467196, -0.0768615 ],
#         [ 0.10890578,  0.16724247, -0.02744468, -0.18578927,  0.08701618],
#         [-0.00770587, -0.15322803,  0.19772147,  0.09441694,  0.18260321]],
#        dtype=float32),
#  array([[ 0.05269759,  0.10805202, -0.04652241, -0.19133395,  0.08971695],
#         [ 0.14658865, -0.02980945, -0.08681314,  0.12862363, -0.09867229],
#         [ 0.02172044, -0.0311836 ,  0.04486779, -0.15840547, -0.05495043],
#         [-0.04161727,  0.00082822, -0.19708917,  0.05349079, -0.09534539]],
#        dtype=float32)]

# %%
words_of_interest=['apple','banana','football','fruit','burger','pizza','cricket','tennis','player','ball','java','python','computer','code','software']

# %%
vectors=[model.wv[w] for w in words_of_interest]
len(vectors)
# Out:
# 15

# %%
vectors=np.array(vectors)

# %%
vectors.shape
# Out:
# (15, 5)

# %% [markdown]
# Reduce the dimensions of these vectors to 2

# %%
pca=PCA(n_components=2)
vectors_2D=pca.fit_transform(vectors)
vectors_2D.shape
# Out:
# (15, 2)

# %%
plt.figure(figsize=(16,9))
plt.scatter(vectors_2D[:,0], vectors_2D[:,1], c='red')
for i,word in enumerate(words_of_interest):
    plt.annotate(word,xy=(vectors_2D[i,0],vectors_2D[i,1]),ha='right',va='bottom')
plt.grid()
plt.show()

# %%
gensim.__version__
# Out:
# '4.4.0'
