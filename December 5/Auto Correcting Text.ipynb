# %%
from textblob import TextBlob

# %%
word='comptar'
blob=TextBlob(word)
blob.correct()
# Out:
# TextBlob("compare")

# %%
word='komputar'
blob=TextBlob(word)
blob.correct()
# Out:
# TextBlob("computer")

# %%
sent='It wes a graet day. When they plaeyad on the gruond.'

# %%
blob=TextBlob(sent)

# %%
blob.correct()
# Out:
# TextBlob("It was a great day. When they played on the ground.")

# %%
blob.word_counts
# Out:
# defaultdict(int,
#             {'it': 1,
#              'wes': 1,
#              'a': 1,
#              'graet': 1,
#              'day': 1,
#              'when': 1,
#              'they': 1,
#              'plaeyad': 1,
#              'on': 1,
#              'the': 1,
#              'gruond': 1})

# %%
sent='It was a great day when they played on the gruond.'
blob=TextBlob(sent)
blob.word_counts
# Out:
# defaultdict(int,
#             {'it': 1,
#              'was': 1,
#              'a': 1,
#              'great': 1,
#              'day': 1,
#              'when': 1,
#              'they': 1,
#              'played': 1,
#              'on': 1,
#              'the': 1,
#              'gruond': 1})

# %%
blob.pos_tags
# Out:
# [('It', 'PRP'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('great', 'JJ'),
#  ('day', 'NN'),
#  ('when', 'WRB'),
#  ('they', 'PRP'),
#  ('played', 'VBD'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('gruond', 'NN')]

# %%
blob.tokenize()
# Out:
# WordList(['It', 'was', 'a', 'great', 'day', 'when', 'they', 'played', 'on', 'the', 'gruond', '.'])

# %%
blob.sentences
# Out:
# [Sentence("It was a great day when they played on the gruond.")]
