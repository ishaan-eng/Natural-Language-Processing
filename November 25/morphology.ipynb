# %%
pip install morfessor polyglot pyciu pucld2 -U
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting morfessor
#   Downloading Morfessor-2.0.6-py3-none-any.whl.metadata (628 bytes)
# Collecting polyglot
#   Downloading polyglot-16.7.4.tar.gz (126 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [26 lines of output]
#       Traceback (most recent call last):
#         File "C:\Users\dai\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#           main()
#           ~~~~^^
#         File "C:\Users\dai\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#           json_out["return_val"] = hook(**hook_input["kwargs"])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\dai\AppData\Roaming\Python\Python313\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 143, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "C:\Users\dai\AppData\Local\Temp\pip-build-env-hh3ia3ii\overlay\Lib\site-packages\setuptools\build_meta.py", line 331, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\dai\AppData\Local\Temp\pip-build-env-hh3ia3ii\overlay\Lib\site-packages\setuptools\build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "C:\Users\dai\AppData\Local\Temp\pip-build-env-hh3ia3ii\overlay\Lib\site-packages\setuptools\build_meta.py", line 512, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\dai\AppData\Local\Temp\pip-build-env-hh3ia3ii\overlay\Lib\site-packages\setuptools\build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 15, in <module>
#         File "C:\Python313\Lib\encodings\cp1252.py", line 23, in decode
#           return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#                  ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#       UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 4941: character maps to <undefined>
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'polyglot' when getting requirements to build wheel

# %%
from polyglot.text import Word

# %%
words=['cats','computing','association','programming','leadership','miscommunication','identifiable','psychologically','engineering','tabular','realistic','colorfulness']

# %%
for w in words:
    w=Word(w,language='en')
    print(w,'\t\r',w.morphemes)
